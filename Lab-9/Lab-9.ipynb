# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from IPython.display import display

# %%
# 1
df = pd.read_csv("sentiments.csv")
df = df.drop(columns = ['user', 'date'])
display(df)

# 2
df.head()

# 3
df['text'] = df['text'].apply(lambda x: x.lower())

# 4
df['text_length'] = df['text'].apply(lambda x: len(x))

# 5
df['word_count'] = df['text'].apply(lambda x: len(x.split()))

# 6
df['sentiment'].value_counts()

# 7
sentiment_counts = df['sentiment'].value_counts()
plt.bar(sentiment_counts.index, sentiment_counts.values)
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.title('Sentiment Distribution')
plt.show()

# 8
df[['sentiment', 'word_count']].groupby(['sentiment']).mean().round(2)

# 9
df.loc[df['word_count'].idxmax(), 'text':'sentiment']

# 10
plt.hist(df['word_count'], bins=5)
plt.xlabel('Word Count')
plt.ylabel('Distribution')
plt.title('Word Count Distribution')
plt.show()

display(df)
# Out:
#                                                  text sentiment
# 0                              Not recommended at all  negative
# 1                       Testing the application today   neutral
# 2                             This made my day better  positive
# 3                        The update ruined everything  negative
# 4                    This is the worst thing I bought  negative
# ..                                                ...       ...
# 146                         The package was delivered   neutral
# 147                     Reading the documentation now   neutral
# 148            Trying this product for the first time   neutral
# 149                     Testing the application today   neutral
# 150  Last session of the day http://twitpic.com/67ezh   neutral
#
# [151 rows x 2 columns]
#                                                  text sentiment  text_length  \
# 0                              not recommended at all  negative           22
# ...

# %%
# 2
df.head()
# Out:
#                                text sentiment
# 0            Not recommended at all  negative
# 1     Testing the application today   neutral
# 2           This made my day better  positive
# 3      The update ruined everything  negative
# 4  This is the worst thing I bought  negative

# %%
# 3
df['text'] = df['text'].apply(lambda x: x.lower())

# %%
# 4
df['text_length'] = df['text'].apply(lambda x: len(x))

# %%
# 5
df['word_count'] = df['text'].apply(lambda x: len(x.split()))

# %%
# 6
df['sentiment'].value_counts()
# Out:
# sentiment
# neutral     57
# positive    49
# negative    45
# Name: count, dtype: int64

# %%
# 7
sentiment_counts = df['sentiment'].value_counts()
plt.bar(sentiment_counts.index, sentiment_counts.values)
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.title('Sentiment Distribution')
plt.show()

# %%
# 8
df[['sentiment', 'word_count']].groupby(['sentiment']).mean().round(2)
# Out:
#            word_count
# sentiment
# negative         3.91
# neutral          4.75
# positive         4.73

# %%
# 9
df.loc[df['word_count'].idxmax(), 'text':'sentiment']
# Out:
# text         this is the worst thing i bought
# sentiment                            negative
# Name: 4, dtype: object

# %%
# 10
plt.hist(df['word_count'], bins=5)
plt.xlabel('Word Count')
plt.ylabel('Distribution')
plt.title('Word Count Distribution')
plt.show()

# %%
display(df)
# Out:
#                                                  text sentiment  text_length  \
# 0                              not recommended at all  negative           22
# 1                       testing the application today   neutral           29
# 2                             this made my day better  positive           23
# 3                        the update ruined everything  negative           28
# 4                    this is the worst thing i bought  negative           32
# ..                                                ...       ...          ...
# 146                         the package was delivered   neutral           25
# 147                     reading the documentation now   neutral           29
# 148            trying this product for the first time   neutral           38
# 149                     testing the application today   neutral           29
# 150  last session of the day http://twitpic.com/67ezh   neutral           48
#
#      word_count
# 0             4
# ...
