# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import display

# %%
mtdf = pd.read_csv("mtcars.csv")
mtdf
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
q1, ax1 = plt.subplots(figsize=(6, 4))
sns.boxplot(data=mtdf, x="am", y="mpg", ax=ax1)
ax1.set_title("Transmission Type vs MPG")
plt.show()
q1.savefig("ttvsmpg.png", dpi=300, bbox_inches="tight")

q2, ax2 = plt.subplots(figsize=(6, 4))
ax2.scatter(x=mtdf["hp"], y=mtdf["mpg"])
ax2.set_title("HP vs MPG")
ax2.set_xlabel("HP")
ax2.set_ylabel("MPG")
plt.show()
q2.savefig("hpvsmpg.png", dpi=300, bbox_inches="tight")

q2, ax3 = plt.subplots(figsize=(6, 4))
ax3.scatter(x=mtdf["wt"], y=mtdf["mpg"])
ax3.set_title("Weight vs Mileage")
ax3.set_xlabel("Weight")
ax3.set_ylabel("MPG")
plt.show()
q2.savefig("wtvsmpg.png", dpi=300, bbox_inches="tight")

# %%
cdf = pd.read_csv("cereals.csv")
cdf
# Out:
#                  name  calories  protein  fat    sodium  fiber  carbohydrates  \
# 0         Corn Flakes     100.0      2.0  0.0  200.0000    1.0      22.000000
# 1      Frosted Flakes     105.0      2.0  0.0  210.0000    1.0      23.000000
# 2            Cheerios     120.0      3.0  2.0  210.9375    2.0      21.000000
# 3       Rice Krispies      90.0      2.0  0.0  220.0000    1.0      24.000000
# 4           Special K     110.0      2.5  1.0  213.7500    3.0      20.000000
# 5         Cocoa Puffs     105.0      1.0  1.0  211.8750    1.0      25.000000
# 6         Fruit Loops     105.0      2.0  1.0  210.9375    2.0      22.666667
# 7      Shredded Wheat     100.0      3.0  1.0  200.0000    3.0      22.000000
# 8  Honey Nut Cheerios     110.0      3.0  2.0  210.0000    2.0      21.000000
# 9         Raisin Bran     105.0      4.0  2.0  213.7500    4.0      26.000000
#
#    sugars  vitamins
# 0     9.0      25.0
# 1    12.0      25.0
# 2     6.0      25.0
# 3    10.0      25.0
# ...

# %%
numeric_cols = cdf.loc[:, "calories":"vitamins"].columns

# %%
# cdf.boxplot()
sns.boxplot(data=cdf)
# Out:
# <Axes: >

# %% [markdown]
# ## Question 2

# %%
cdf.plot.bar(x="name", y="calories", rot=90)
# Out:
# <Axes: xlabel='name'>

# %%
cdf.boxplot(column="sugars")
# Out:
# <Axes: >

# %%
healthy_cereals = cdf.loc[(cdf["sugars"] < 5) & (cdf["fiber"] > 5) & (cdf["calories"] <= cdf["calories"].median()), :]
healthy_cereals.value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
cdf.plot.scatter(x="fiber", y="sugars")
# Out:
# <Axes: xlabel='fiber', ylabel='sugars'>

# %%
cdf.plot.scatter?
# Out:
# Signature:
# cdf.plot.scatter(
#     x: 'Hashable',
#     y: 'Hashable',
#     s: 'Hashable | Sequence[Hashable] | None' = None,
#     c: 'Hashable | Sequence[Hashable] | None' = None,
#     **kwargs,
# ) -> 'PlotAccessor'
# Docstring:
# Create a scatter plot with varying marker point size and color.
#
# The coordinates of each point are defined by two dataframe columns and
# filled circles are used to represent each point. This kind of plot is
# useful to see complex correlations between two variables. Points could
# be for instance natural 2D coordinates like longitude and latitude in
# a map or, in general, any pair of metrics that can be plotted against
# each other.
#
# Parameters
# ----------
# x : int or str
#     The column name or column position to be used as horizontal
#     coordinates for each point.
# y : int or str
#     The column name or column position to be used as vertical
#     coordinates for each point.
# s : str, scalar or array-like, optional
# ...
